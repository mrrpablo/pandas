# %% [markdown]
# import matplotlib.pyplot as plt
# import numpy as np
#
# xpoint = np.array([0, 10])
# ypoint = np.array([0, 200])
#
# plt.plot(xpoint, ypoint)
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoint = np.array([5, 2, 1, 4, 8, 4, 10, 15])
ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(xpoint, ypoint, "o")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoint = np.array([5, 2, 1, 4, 8, 4, 10, 15])
ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(xpoint, ypoint)
plt.show()

# %% [markdown]
# # Matplotlib Markers

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, marker = "o")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, marker = "*")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, marker = ".")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, marker = "x")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, marker = "+") #normal '+' marker
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, marker = "P") #bold '+' marker
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, marker = "s") #square marker
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, marker = "D") #diamond marker
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, marker = "d") #small diamond marker
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, marker = "h") #hexagonal marker
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, marker = ">") 
plt.show()

# %% [markdown]
# ## Format String

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, "o:r")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, ">-r")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, ">--r")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, "o-.r")
plt.show()

# %% [markdown]
# ## Color reference

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, ">-.b")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, ">-.c")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, ">-.k")
plt.show()

# %% [markdown]
# ## Marker Size

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, marker = "s", ms = 10)
plt.show()

# %% [markdown]
# ## Marker color

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, marker = "s", ms = 10, mec = "r")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, marker = "s", ms = 10, mfc = "r")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, marker = "o", ms = 10, mec = "r", mfc = "b")
plt.show()

# %% [markdown]
# ## Line Style

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, linestyle = "dotted")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, linestyle = "dashed")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, ls = ":")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, color = "red")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array([3, 1, 3, 5, 10, 3, 9, 7])

plt.plot(ypoint, linewidth = "5")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoint = np.array([4, 8, 16, 20])
ypoint = np.array([2, 6, 14, 18])

plt.plot(xpoint)
plt.plot(ypoint)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoint = np.array([4, 20])
ypoint = np.array([2, 18])

plt.plot(xpoint)
plt.plot(ypoint)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoint = np.array([4, 20])
ypoint = np.array([2, 18])
xpoint1 = np.array([4, 20])
ypoint1 = np.array([2, 18])

plt.plot(xpoint, xpoint1, ypoint, ypoint1)
plt.show()

# %% [markdown]
# ## Matplotlib Labels and Tiles

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([36.58, 36.02])
y = np.array([17.90, 17.93])

font1 = {"family": "serif", "color": "red", "size":18}
font2 = {"family": "arial", "color": "k", "size":18}
plt.xlabel("retroo", fontdict = font1)
plt.ylabel("pablo", fontdict = font1)
plt.title("Precious bassey",  fontdict = font2) 

plt.plot(x)
plt.plot(y)
plt.show()

# %% [markdown]
# ## Assignment

# %% [markdown]
# ### observation: if i plot without identifying "road_x" & "road_y" the plot won't join, it will only bring a straight line, reason why i have road_x and road_y

# %%
import matplotlib.pyplot as plt
import numpy as np

phone_number = 7041291284

Easting = np.array([7041291286, 7041291286, 7041291297, 7041291297, 7041291286])
Northing = np.array([7041291294, 7041291304, 7041291304, 7041291294, 7041291294])
road_x = np.array([7041291291, 7041291309])
road_y = np.array([7041291291, 7041291309])

font = {"family": "arial", "size": 20}

plt.plot(Easting, Northing, color = "red", marker = "s")
plt.plot(road_x, road_y, color = "black", ls = "--")
plt.title("Precious Bassey", loc = "right", fontdict = font, color = "cyan")

plt.show()

# %% [markdown]
# ## Without phone num

# %%
import matplotlib.pyplot as plt
import numpy as np


Easting = np.array([2, 2, 13, 13, 2])
Northing = np.array([10, 20, 20, 10, 10])
road_x = np.array([7, 25])


font = {"family": "arial", "size": 20}

plt.plot(Easting, Northing, color = "red", marker = "s")
plt.plot(road_x, color = "black", ls = "--")
plt.title("Precious Bassey", loc = "right", fontdict = font, color = "cyan")

plt.show()

# %% [markdown]
# ## Matplotlib grid

# %%
import matplotlib.pyplot as plt
import numpy as np

#northing and easting
Easting = np.array([2, 2, 13, 13, 2])
Northing = np.array([10, 20, 20, 10, 10])

#road
road_x = np.array([7, 25])

#font
font = {"family": "arial", "size": 20}

#plotting
plt.plot(Easting, Northing, color = "red", marker = "s")
plt.plot(road_x, color = "black", ls = "--")
plt.title("Precious Bassey", loc = "right", fontdict = font, color = "cyan")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#northing and easting
Easting = np.array([2, 2, 13, 13, 2])
Northing = np.array([10, 20, 20, 10, 10])

#road
road_x = np.array([7, 25])

#font
font = {"family": "arial", "size": 20}

#plotting
plt.plot(Easting, Northing, color = "red", marker = "s")
plt.plot(road_x, color = "black", ls = "--")
plt.title("Precious Bassey", loc = "right", fontdict = font, color = "cyan")
plt.grid(axis = "x")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#northing and easting
Easting = np.array([2, 2, 13, 13, 2])
Northing = np.array([10, 20, 20, 10, 10])

#road
road_x = np.array([7, 25])

#font
font = {"family": "arial", "size": 20}

#plotting
plt.plot(Easting, Northing, color = "red", marker = "s")
plt.plot(road_x, color = "black", ls = "--")
plt.title("Precious Bassey", loc = "right", fontdict = font, color = "cyan")
plt.grid(axis = "y")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#northing and easting
Easting = np.array([2, 2, 13, 13, 2])
Northing = np.array([10, 20, 20, 10, 10])

#road
road_x = np.array([7, 25])

#font
font = {"family": "arial", "size": 20}

#plotting
plt.plot(Easting, Northing, color = "red", marker = "s")
plt.plot(road_x, color = "black", ls = "--")
plt.title("Precious Bassey", loc = "right", fontdict = font, color = "cyan")
plt.grid(color = "blue", ls = "--", linewidth = "0.5")
plt.show()

# %% [markdown]
# # Matplotlib Subplot

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1
xpoint = np.array([4, 20])
ypoint = np.array([2, 18])

plt.subplot(2, 3, 1) # 2 = row, 2 = column, 2 = location/position
plt.plot(xpoint)
plt.plot(ypoint)
plt.title("Precious Bassey", loc = "right", fontdict = font, color = "cyan")
plt.xlabel("retroo")
plt.ylabel("pablo")

# plot 2
#northing and easting
Easting = np.array([2, 2, 13, 13, 2])
Northing = np.array([10, 20, 20, 10, 10])
plt.subplot(2, 3, 2)
plt.plot(Easting, Northing, color = "red", marker = "s")

#plot 3
x =  np.array([5, 21])
y = np.array([21, 8])
plt.subplot(2, 3, 3)
plt.plot(x, y)

#plot 4 
x =  np.array([2, 4])
y = np.array([8, 12])
plt.subplot(2, 3, 5)
plt.plot(x, y)

#plot 5 
x =  np.array([2, 4])
y = np.array([8, 12])
plt.subplot(2, 3, 6)
plt.plot(x, y)

#plot 6 
x =  np.array([4, 15, 35, 120])
plt.subplot(2, 3, 4)
plt.plot(x)


plt.grid()
plt.show()

# %% [markdown]
# ## Assignment II

# %%
import matplotlib.pyplot as plt
import numpy as np


#plot 1
x = np.array([4, 15, 35, 120])

plt.subplot(2, 3, 1) # 2 = row, 2 = column, 2 = location/position
plt.plot(x)
plt.title("Blake")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(axis = "x")

# plot 2
long =  np.array([2, 2, 13, 13, 2])
lat = np.array([10, 20, 20, 10, 10])

plt.subplot(2, 3, 2)
plt.title("Collins")
plt.plot(long, lat, color = "blue", marker = "s")
plt.grid(axis = "x")

#plot 3
y = np.array([21, 8, 15, 77, 13])

plt.subplot(2, 3, 3)
plt.title("Stella")
plt.plot(y, color = "r")
plt.grid(axis = "y")

#plot 4 
x =  np.array([-2, -4, 10])
y = np.array([-8, 12, -1])

plt.subplot(2, 3, 4)
plt.title("Pablo")
plt.plot(x, y, color = "y")
plt.grid()

#plot 5 
x =  np.array([21, 7, 14, 5, 16, 6, 32, 19])
y = np.array([81, 65, 2, 8, 6, 12, 16, 9])

plt.subplot(2, 3, 5)
plt.title("Sterling")
plt.plot(x, y, color = "green")
plt.grid()

#plot 6 
x =  np.array([21,14, 7])
y =  np.array([8, 6, 4])

plt.subplot(2, 3, 6)
plt.title("Steph")
plt.plot(x, y)
plt.grid(axis = "x")


plt.suptitle("Ezie Victor Erus Graph")
plt.show()

# %% [markdown]
# ## Matplotlib scatter plot

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([2, 4, 6, 7, 8, 10, 3, 5, 7, 3, 15])
y = np.array([12, 42, 6, 47, 8, 10, 3, 15, 7, 13, 15])
plt.scatter(x,y)

x = np.array([4, 6, 8, 1, 0, 6])
y = np.array([2, 5, 12, 10, 20, 16])
plt.scatter(x,y)

plt.title("retroo")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([4, 6, 8, 1, 0, 6])
y = np.array([2, 5, 12, 10, 20, 16])
colors = np.array(["r", "g", "b", "cyan", "k", "y"])
plt.scatter(x, y, c = colors)

plt.title("retroo")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([4, 6, 8, 1, 0, 6])
y = np.array([2, 5, 12, 10, 20, 16])
colors = np.array([0, 10, 20, 30, 40, 50])
plt.scatter(x, y, c = colors, cmap = "viridis")
plt.colorbar()
plt.title("retroo")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([4, 6, 8, 1, 0, 6])
y = np.array([2, 5, 12, 10, 20, 16])
colors = np.array([0, 10, 20, 30, 40, 50])
plt.scatter(x, y, c = colors, cmap = "Accent")
plt.colorbar()
plt.title("retroo")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([4, 6, 8, 1, 0, 6])
y = np.array([2, 5, 12, 10, 20, 16])
colors = np.array([0, 10, 20, 30, 40, 50])
plt.scatter(x, y, c = colors, cmap = "Blues")
plt.colorbar()
plt.title("retroo")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([4, 6, 8, 1, 0, 6])
y = np.array([2, 5, 12, 10, 20, 16])
colors = np.array([0, 10, 20, 30, 40, 50])
plt.scatter(x, y, c = colors, cmap = "BrBG")
plt.colorbar()
plt.title("retroo")
plt.show()

# %% [markdown]
# ## Size

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([4, 6, 8, 1, 0, 6])
y = np.array([2, 5, 12, 10, 20, 16])
size = np.array([10, 100, 200, 300, 400, 500])
plt.scatter(x, y, s = size)
plt.colorbar()
plt.title("retroo")
plt.show()

# %% [markdown]
# ## Alpha

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([4, 6, 8, 1, 0, 6])
y = np.array([2, 5, 12, 10, 20, 16])
size = np.array([10, 100, 200, 300, 400, 500])
plt.scatter(x, y, s = size, alpha = 0.5)
plt.colorbar()
plt.title("retroo")
plt.show()

# %% [markdown]
# ## Combime color, size & alpha

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size = (100))
y = np.random.randint(100, size = (100))
colors = np.random.randint(100, size = (100))
sizes = np.random.randint(100, size = (100))

plt.scatter(x, y, c = colors, s = sizes, alpha = 0.5, cmap = "nipy_spectral")
plt.colorbar()
plt.title("retroo")
plt.show()

# %% [markdown]
# ## Matplotlib bar

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Collins", "Blake", "Nulu", "Steph"])
y = np.array([4, 13, 5, 9])

plt.bar(x, y)
plt.show()

# %% [markdown]
# ## Assignment III

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ([
    0.1569, 0.8743, 0.3917, 0.2870, 0.9984, 0.6111, 0.4552, 0.7683, 0.5781, 0.0511,
    0.3154, 0.1453, 0.7602, 0.6851, 0.2864, 0.5192, 0.6549, 0.9375, 0.3242, 0.7558,
    0.2735, 0.4964, 0.3894, 0.8407, 0.7101, 0.1681, 0.6324, 0.5684, 0.4361, 0.1576,
    0.6631, 0.7922, 0.4205, 0.2452, 0.7244, 0.5129, 0.1748, 0.8511, 0.9417, 0.3171,
    0.4924, 0.7039, 0.4053, 0.8974, 0.6081, 0.2106, 0.3591, 0.2804, 0.4967, 0.1384
])

y = ([
    0.8473, 0.1329, 0.4327, 0.5607, 0.2094, 0.4371, 0.6159, 0.9320, 0.7306, 0.3491,
    0.7429, 0.6513, 0.4821, 0.3064, 0.8704, 0.5763, 0.1235, 0.8476, 0.2871, 0.9362,
    0.6394, 0.7384, 0.5487, 0.1924, 0.5683, 0.2937, 0.8415, 0.4708, 0.5120, 0.7462,
    0.3764, 0.8904, 0.1328, 0.4962, 0.3198, 0.7483, 0.3642, 0.2104, 0.4392, 0.9834,
    0.5623, 0.3876, 0.5294, 0.2471, 0.4081, 0.6534, 0.7812, 0.9021, 0.3541, 0.6738
])

colors = np.random.rand(50)
plt.scatter(x, y, c = colors, alpha = 0.5)
plt.colorbar()
plt.show()

# %% [markdown]
# ## Bar Color

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Collins", "Blake", "Nulu", "Steph"])
y = np.array([4, 13, 5, 9])

plt.barh(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Collins", "Blake", "Nulu", "Steph"])
y = np.array([4, 13, 5, 9])

plt.bar(x, y, color = "green")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Collins", "Blake", "Nulu", "Steph"])
y = np.array([4, 13, 5, 9])

plt.barh(x, y, color = "black")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Collins", "Blake", "Nulu", "Steph"])
y = np.array([4, 13, 5, 9])

plt.barh(x, y, color = "#5DE2E7")
plt.show()

# %% [markdown]
# ## Bar Width

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Collins", "Blake", "Nulu", "Steph"])
y = np.array([4, 13, 5, 9])

plt.bar(x, y, width = 0.8, color = "#5b19eb")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Collins", "Blake", "Nulu", "Steph"])
y = np.array([4, 13, 5, 9])

plt.barh(x, y, height = 0.8, color = "#5b19eb")
plt.show()

# %% [markdown]
# # Matplotlib Histogram

# %%
import numpy as np

x = np.random.normal(170, 10, 250)
# First = value to concentrate, Second number = standard deviation, third = how many values
print(x)
# Out:
# [166.67444942 168.47767415 153.5140046  173.66019878 180.61479869
#  166.58062626 169.12729801 166.5596178  172.25969134 167.21773
#  148.9641707  184.62899476 178.36142103 151.90018725 164.85863627
#  160.58706987 148.97490428 179.0423908  168.30182127 192.45151699
#  167.64564911 188.45828635 155.6695325  174.50258069 159.71316783
#  168.0098527  168.7054152  159.45615292 184.51935767 166.61954415
#  144.17312386 165.63335485 168.34600435 160.42323549 171.9787975
#  169.67951448 190.93251761 171.59957051 155.65021186 185.38099824
#  142.40448723 152.21625562 167.75707536 167.08737313 158.5015261
#  151.51179992 157.84349435 179.47208003 162.75971263 163.13431718
#  170.36876346 168.76050146 177.19054894 175.06509149 168.55371395
#  183.23460089 161.83125182 189.65141607 164.78983579 164.18597692
#  173.97630081 170.56982117 163.62263119 163.42563605 179.78995136
#  162.51236042 170.36660463 180.05923554 167.74594835 176.03326392
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)
plt.hist(x)
plt.show()

# %% [markdown]
# ## Matplotlib Pie chart

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([170, 10, 250])
plt.pie(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([45, 45, 45, 45, 45, 45, 45, 45])
plt.pie(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([90, 45, 45, 45, 45, 45])
plt.pie(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([180, 45, 45, 45, 45]) # x / sum(X) formula
plt.pie(x)
plt.show()

# %% [markdown]
# ## Pie Label

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([90, 45, 45, 45, 45]) # x / sum(X) formula
myLabels = ["Steph", "Pablo", "Nulu", "Stella", "Sterling"]

plt.pie(x, labels = myLabels, startangle = 45)
plt.show()

# %% [markdown]
# ## Start Angle

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([90, 45, 45, 45, 45]) # x / sum(X) formula
myLabels = ["Steph", "Pablo", "Nulu", "Stella", "Sterling"]

plt.pie(x, labels = myLabels, startangle = 45)
plt.show()

# %% [markdown]
# ## Explode

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([90, 45, 45, 45, 45]) # x / sum(X) formula
myLabels = ["Steph", "Pablo", "Nulu", "Stella", "Sterling"]
myexplode = [0, 0.1, 0, 0, 0]

plt.pie(x, labels = myLabels, startangle = 0, explode = myexplode)
plt.show()

# %% [markdown]
# ## Shadow

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([90, 45, 45, 45, 45]) # x / sum(X) formula
myLabels = ["Steph", "Pablo", "Nulu", "Stella", "Sterling"]
myexplode = [0, 0, 0, 0, 0.2]

plt.pie(x, labels = myLabels, startangle = 0, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# ## Color

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([90, 45, 45, 45, 45]) # x / sum(X) formula
myLabels = ["Steph", "Pablo", "Nulu", "Stella", "Sterling"]
myexplode = [0, 0, 0, 0, 0.3]
mycolor = ["black", "blue", "green", "yellow", "red"]

plt.pie(x, labels = myLabels, startangle = 0, explode = myexplode, shadow = True, colors = mycolor)
plt.show()

# %% [markdown]
# ## Legend

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([90, 45, 45, 45, 45]) # x / sum(X) formula
myLabels = ["Steph", "Pablo", "Nulu", "Stella", "Sterling"]
myexplode = [0, 0, 0, 0, 0.3]
mycolor = ["black", "blue", "green", "yellow", "red"]

plt.pie(x, labels = myLabels, startangle = 0, explode = myexplode, shadow = True, colors = mycolor)
plt.legend(title = "Beginners")
plt.show()
