# %%
import pandas as pd
df = pd.DataFrame(
    {
        "Name": [
            "Precious",
            "Asuquo",
            "Bassey",
        ],
        "Age": [12, 45, 34],
        "State": ["Ebonyi", "Enugu", "Edo"],
    }
  ) 
print(df)
# Out:
#        Name  Age   State
# 0  Precious   12  Ebonyi
# 1    Asuquo   45   Enugu
# 2    Bassey   34     Edo

# %%
df["Age"]
# Out:
# 0    12
# 1    45
# 2    34
# Name: Age, dtype: int64

# %%
df["Age"].min()
# Out:
# np.int64(12)

# %%
df["Name"]
# Out:
# 0    Precious
# 1      Asuquo
# 2      Bassey
# Name: Name, dtype: object

# %%
df["Age"].max()
# Out:
# np.int64(45)

# %%
df["Age"].sum()
# Out:
# np.int64(91)

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   30.333333
# std    16.802778
# min    12.000000
# 25%    23.000000
# 50%    34.000000
# 75%    39.500000
# max    45.000000

# %%
df.head()
# Out:
#        Name  Age   State
# 0  Precious   12  Ebonyi
# 1    Asuquo   45   Enugu
# 2    Bassey   34     Edo

# %%
data = pd.read_csv("data/nigeriahealthfacilities.csv")

# %%
data.head()
# Out:
#    id                        name                             global_id  \
# 0   1          G R A Nursing Home  af719462-abfd-4f47-9dc3-0987164e75ac
# 1   2       Gishili Health Center  a29b0328-d844-4358-b0ab-2e120b8fb30f
# 2   3  Lehobi Primary Health Care  b685b769-5c83-4f83-a182-00e7e1b777d8
# 3   4              Dugja Idp Camp  78e64f7a-cbb8-4357-9e64-a7e502534527
# 4   5   Kopa Maikudiri Dispensary  409c97ce-7490-4dc2-a8f8-2b8d53ad2b12
#
#              alternate_name     functional_status     type ward_code  \
# 0              Nursing Home               Unknown  Primary     12413
# 1              Nursing Home            Functional  Primary     12413
# 2                       NaN  Partially Functional  Primary     10207
# 3  Mandara Girau Dispensary        Not Functional  Primary     10503
# 4                       NaN  Partially Functional  Primary     10209
#
#                 category             timestamp accessibility    lga_name  \
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Desktop\\spatial\\pycharm\\pandas'

# %%
data.dtypes
# Out:
# id                    int64
# name                 object
# global_id            object
# alternate_name       object
# functional_status    object
# type                 object
# ward_code            object
# category             object
# timestamp            object
# accessibility        object
# lga_name             object
# lga_code              int64
# state_code           object
# state_name           object
# FID                  object
# dtype: object

# %%
state = data["name"]
state.head(10)
# Out:
# 0                G R A Nursing Home
# 1             Gishili Health Center
# 2        Lehobi Primary Health Care
# 3                    Dugja Idp Camp
# 4         Kopa Maikudiri Dispensary
# 5          Ghumtukum Medical Center
# 6                  Ghung Dispensary
# 7             Grem Demch Dispensary
# 8    Gumsuri Federal Medical Center
# 9              Uba Bobo Health Post
# Name: name, dtype: object

# %%
data["name"].shape
# Out:
# (46146,)

# %%
namestate = data[["name", "state_name"]]
namestate.head()
# Out:
#                          name state_name
# 0          G R A Nursing Home      Borno
# 1       Gishili Health Center      Borno
# 2  Lehobi Primary Health Care      Borno
# 3              Dugja Idp Camp      Borno
# 4   Kopa Maikudiri Dispensary      Borno

# %%
namestate = data[["name", "type"]]
namestate.head()
# Out:
#                          name     type
# 0          G R A Nursing Home  Primary
# 1       Gishili Health Center  Primary
# 2  Lehobi Primary Health Care  Primary
# 3              Dugja Idp Camp  Primary
# 4   Kopa Maikudiri Dispensary  Primary

# %%
type = data[data["type"] == "Primary"]
type.head()
# Out:
#    id                        name                             global_id  \
# 0   1          G R A Nursing Home  af719462-abfd-4f47-9dc3-0987164e75ac
# 1   2       Gishili Health Center  a29b0328-d844-4358-b0ab-2e120b8fb30f
# 2   3  Lehobi Primary Health Care  b685b769-5c83-4f83-a182-00e7e1b777d8
# 3   4              Dugja Idp Camp  78e64f7a-cbb8-4357-9e64-a7e502534527
# 4   5   Kopa Maikudiri Dispensary  409c97ce-7490-4dc2-a8f8-2b8d53ad2b12
#
#              alternate_name     functional_status     type ward_code  \
# 0              Nursing Home               Unknown  Primary     12413
# 1              Nursing Home            Functional  Primary     12413
# 2                       NaN  Partially Functional  Primary     10207
# 3  Mandara Girau Dispensary        Not Functional  Primary     10503
# 4                       NaN  Partially Functional  Primary     10209
#
#                 category             timestamp accessibility    lga_name  \
# ...

# %%
type = data[data["functional_status"] == "Unknown"]
type.head()
# Out:
#      id                                       name  \
# 0     1                         G R A Nursing Home
# 67   68  Gatamarwa Family Support Programme Clinic
# 73   74                    Lambu 2 Idp Camp Clinic
# 86  176                          Andara Dispensary
# 93   93                           Berum Dispensary
#
#                                global_id           alternate_name  \
# 0   af719462-abfd-4f47-9dc3-0987164e75ac             Nursing Home
# 67  a36bd78d-e979-4ca9-9e99-3a095a2bd560  Gatamarwa Health Center
# 73  69e82d60-6baf-44ac-ab24-7eead41ffc48                      NaN
# 86  3c73221c-8077-4f83-998e-d9bbaa177e73                      NaN
# 93  304acd6c-ffa2-48f2-96dd-06be45928431                      NaN
#
#    functional_status     type ward_code               category  \
# 0            Unknown  Primary     12413  Primary Health Center
# 67           Unknown  Primary     10611  Primary Health Center
# 73           Unknown  Primary     11311  Primary Health Center
# ...

# %%
data[data["functional_status"] == "Unknown"].shape
# Out:
# (11753, 15)

# %%
type = data[data["functional_status"] == "Functional"]
type.head()
# Out:
#     id                       name                             global_id  \
# 1    2      Gishili Health Center  a29b0328-d844-4358-b0ab-2e120b8fb30f
# 5    6   Ghumtukum Medical Center  6afd9e7a-b985-4cd5-b0cf-f9488500a3a0
# 6    7           Ghung Dispensary  50e5c971-d348-4c81-ba29-f806eefe9920
# 9   10       Uba Bobo Health Post  5a3864b5-d66b-4683-90cd-9c76af393450
# 11  12  Anguwan Banki Health Post  6405d2a0-d828-4509-a1fe-d09d6387d284
#
#          alternate_name functional_status     type ward_code  \
# 1          Nursing Home        Functional  Primary     12413
# 5   Atla Medical Center        Functional  Primary     12413
# 6                   NaN        Functional  Primary     11112
# 9                   NaN        Functional  Primary     10211
# 11                  NaN        Functional  Primary     10403
#
#                  category             timestamp accessibility    lga_name  \
# 1   Primary Health Center  2020-07-04T13:49:18Z       Unknown   Maiduguri
# ...

# %%
data[data["functional_status"] == "Functional"].shape
# Out:
# (34282, 15)

# %%
type = data[data["functional_status"] == "Not Functional"]
type.head()
# Out:
#     id                            name                             global_id  \
# 3    4                  Dugja Idp Camp  78e64f7a-cbb8-4357-9e64-a7e502534527
# 8    9  Gumsuri Federal Medical Center  9c2b58dd-1e99-49b9-970e-eabce1c7dd10
# 10  11          Kangarwa Health Clinic  9084ffc4-0fa7-48e9-abdf-6340bf8881cd
# 14  15             Wajiroko Dispensary  2d477eae-d443-4648-8297-b6fa3145a321
# 16  17      Meleri Primary Health Care  ddc5d870-a8d4-497d-9726-af5c57027271
#
#                   alternate_name functional_status       type ward_code  \
# 3       Mandara Girau Dispensary    Not Functional    Primary     10503
# 8                            NaN    Not Functional  Secondary     10710
# 10  Cocin Rural Health Programme    Not Functional    Primary     10111
# 14                           NaN    Not Functional    Primary     10701
# 16                           NaN    Not Functional    Primary     12205
#
# ...

# %%
data[data["functional_status"] == "Not Functional"].shape
# Out:
# (104, 15)

# %%
lga = data[data["lga_code"] < 102]
lga.head()
# Out:
#       id                          name                             global_id  \
# 10    11        Kangarwa Health Clinic  9084ffc4-0fa7-48e9-abdf-6340bf8881cd
# 33    34       Tumbun Guni Health Post  7ac23f05-af3c-46b6-9cd5-dcc9190d4be4
# 101  101        Yawa Veterinary Clinic  e02e50bf-6899-4a33-a803-e179f51a926b
# 149  149  Mallam Kaunari Health Clinic  ba9a01fe-c8cb-4427-92e9-db3658284a52
# 174  174             Busuna Dispensary  a1d5836e-60b9-4637-84d1-f7091047cd48
#
#                    alternate_name functional_status     type ward_code  \
# 10   Cocin Rural Health Programme    Not Functional  Primary     10111
# 33                            NaN    Not Functional  Primary     10101
# 101                           NaN           Unknown  Primary     10109
# 149                           NaN        Functional  Primary     10111
# 174                           NaN           Unknown  Primary     10111
#
#                   category             timestamp accessibility lga_name  \
# ...

# %%
data[data["lga_code"] < 102].shape
# Out:
# (13, 15)

# %%
data["lga_code"] > 100
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 46141    True
# 46142    True
# 46143    True
# 46144    True
# 46145    True
# Name: lga_code, Length: 46146, dtype: bool

# %%
classxx = data[data["lga_code"].isin ([102,13])]

# %%
classxx.head()
# Out:
#     id                        name                             global_id  \
# 2    3  Lehobi Primary Health Care  b685b769-5c83-4f83-a182-00e7e1b777d8
# 4    5   Kopa Maikudiri Dispensary  409c97ce-7490-4dc2-a8f8-2b8d53ad2b12
# 9   10        Uba Bobo Health Post  5a3864b5-d66b-4683-90cd-9c76af393450
# 15  16  Ngulde Primary Health Care  cfe845eb-9f71-4b99-9603-d2f389a73ba0
# 75  76            Dille Dispensary  b3580a0a-6fce-493e-bb67-515737f93efc
#
#    alternate_name     functional_status     type ward_code  \
# 2             NaN  Partially Functional  Primary     10207
# 4             NaN  Partially Functional  Primary     10209
# 9             NaN            Functional  Primary     10211
# 15            NaN            Functional  Primary     10208
# 75            NaN            Functional  Primary     10212
#
#                  category             timestamp accessibility    lga_name  \
# 2   Primary Health Center  2020-07-04T13:49:18Z           NaN  Askira Uba
# ...

# %%
state_name = data.loc[data["lga_code"] < 102, "state_name"]
state_name.head()
# Out:
# 10     Borno
# 33     Borno
# 101    Borno
# 149    Borno
# 174    Borno
# Name: state_name, dtype: object

# %%
state_name = data.loc[data["lga_code"] == 102, "state_name"]
state_name.head()
# Out:
# 2     Borno
# 4     Borno
# 9     Borno
# 15    Borno
# 75    Borno
# Name: state_name, dtype: object

# %%
state_name = data.loc[data["lga_code"] < 202, "timestamp"]
state_name.head()
# Out:
# 0    2020-07-04T13:49:18Z
# 1    2020-07-04T13:49:18Z
# 2    2020-07-04T13:49:18Z
# 3    2020-07-04T13:49:18Z
# 4    2020-07-04T13:49:18Z
# Name: timestamp, dtype: object

# %%
state_name = data.loc[data["lga_code"] == 13016, "timestamp"]
state_name.head()
# Out:
# 6626    2019-11-15T17:29:44Z
# 8164    2019-06-14T10:17:38Z
# 8165    2019-06-14T10:17:38Z
# 8625    2019-11-15T17:15:50Z
# 9401    2019-11-15T17:15:50Z
# Name: timestamp, dtype: object

# %%
data.iloc[0:2, 1:9]
# Out:
#                     name                             global_id alternate_name  \
# 0     G R A Nursing Home  af719462-abfd-4f47-9dc3-0987164e75ac   Nursing Home
# 1  Gishili Health Center  a29b0328-d844-4358-b0ab-2e120b8fb30f   Nursing Home
#
#   functional_status     type ward_code               category  \
# 0           Unknown  Primary     12413  Primary Health Center
# 1        Functional  Primary     12413  Primary Health Center
#
#               timestamp
# 0  2020-07-04T13:49:18Z
# 1  2020-07-04T13:49:18Z

# %%
data.iloc[0:1,1] = "Pablo"
data.head()
# Out:
#    id                        name                             global_id  \
# 0   1                       Pablo                                 Pablo
# 1   2       Gishili Health Center  a29b0328-d844-4358-b0ab-2e120b8fb30f
# 2   3  Lehobi Primary Health Care  b685b769-5c83-4f83-a182-00e7e1b777d8
# 3   4              Dugja Idp Camp  78e64f7a-cbb8-4357-9e64-a7e502534527
# 4   5   Kopa Maikudiri Dispensary  409c97ce-7490-4dc2-a8f8-2b8d53ad2b12
#
#              alternate_name     functional_status     type ward_code  \
# 0              Nursing Home               Unknown  Primary     12413
# 1              Nursing Home            Functional  Primary     12413
# 2                       NaN  Partially Functional  Primary     10207
# 3  Mandara Girau Dispensary        Not Functional  Primary     10503
# 4                       NaN  Partially Functional  Primary     10209
#
#                 category             timestamp accessibility    lga_name  \
# ...
